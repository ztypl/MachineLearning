# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.preprocessing
import sklearn.linear_model
import sklearn.datasets
# %matplotlib inline

# %%
n_sample = 10
sigma = 0.15

X = np.linspace(0.0, 1.0, n_sample)
Y = np.sin(X*2*np.pi)+np.random.normal(0.0, sigma, X.size)

real_x = np.linspace(0.0, 1.0, 10000)
real_y = np.sin(real_x*2*np.pi)

# %%
plt.xlim(-0.1,1.1)
plt.ylim(-1.2, 1.2)
plt.xticks([0,1])
plt.yticks([-1,0,1])
plt.plot(X, Y, "o")
plt.plot(real_x, real_y)

# %%
degree = 2
poly = sklearn.preprocessing.PolynomialFeatures(degree, include_bias=False)
X_ = poly.fit_transform(X.reshape(-1,1))
model = sklearn.linear_model.LinearRegression()
model.fit(X_, Y)
predict_y = model.predict(poly.fit_transform(real_x.reshape(-1, 1)))

plt.xlim(-0.1,1.1)
plt.ylim(-1.2, 1.2)
plt.xticks([0,1])
plt.yticks([-1,0,1])
plt.plot(X, Y, "o")
plt.plot(real_x, real_y)
plt.plot(real_x, predict_y, color='b')

# %%
degree = 4
poly = sklearn.preprocessing.PolynomialFeatures(degree, include_bias=False)
X_ = poly.fit_transform(X.reshape(-1,1))
model = sklearn.linear_model.LinearRegression()
model.fit(X_, Y)
predict_y = model.predict(poly.fit_transform(real_x.reshape(-1, 1)))

plt.xlim(-0.1,1.1)
plt.ylim(-1.2, 1.2)
plt.xticks([0,1])
plt.yticks([-1,0,1])
plt.plot(X, Y, "o")
plt.plot(real_x, real_y)
plt.plot(real_x, predict_y, color='b')

# %%
degree = 9
poly = sklearn.preprocessing.PolynomialFeatures(degree, include_bias=False)
X_ = poly.fit_transform(X.reshape(-1,1))
model = sklearn.linear_model.LinearRegression()
model.fit(X_, Y)
predict_y = model.predict(poly.fit_transform(real_x.reshape(-1, 1)))

plt.xlim(-0.1,1.1)
plt.ylim(-1.2, 1.2)
plt.xticks([0,1])
plt.yticks([-1,0,1])
plt.plot(X, Y, "o")
plt.plot(real_x, real_y)
plt.plot(real_x, predict_y, color='b')
