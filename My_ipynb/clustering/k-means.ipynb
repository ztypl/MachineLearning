# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics.pairwise import pairwise_distances_argmin

# %%
X, y = make_blobs(n_samples=3000, centers=3, n_features=2, cluster_std=0.7, random_state=0)
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Spectral)

# %%
model = KMeans(n_clusters=3)
y_pred = model.fit_predict(X)

# %%
model.cluster_centers_
# Out:
# array([[-1.52324237,  2.92115492],
#        [ 2.007231  ,  0.90899235],
#        [ 0.96354624,  4.31210254]])

# %%
y_pred
# Out:
# array([1, 2, 0, ..., 2, 0, 0], dtype=int32)

# %%
plt.scatter(X[:,0], X[:,1], c=y_pred, cmap=plt.cm.Spectral)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], marker='x', c='k')

# %%
# pairwise_accuracy
